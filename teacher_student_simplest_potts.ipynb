# %%
import sys
sys.path.append('..')

import utils, selex_dca, indep_sites
import adabmDCA
import selex_distribution, energy_models, tree, data_loading, training, callback, sampling

import torch
from utils import one_hot
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
# Out:
# /home/scrotti/Aptamer2025py/selex_dca.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
dtype = torch.float32

# %% [markdown]
# ## Generate

# %%
import importlib
importlib.reload(utils)
importlib.reload(selex_distribution)
importlib.reload(energy_models)
importlib.reload(sampling)
importlib.reload(training)
importlib.reload(callback)
# Out:
# <module 'callback' from '/home/scrotti/Aptamer2025py/callback.py'>

# %%
L, q = 45, 4

tr = tree.Tree()
tr.add_node(-1, name = "round 1 with selection")
tr.add_node(0, name = "round 2 with selection")

selected_modes = torch.BoolTensor(
    [[1],
     [1]]
)

n_selection_rounds, n_modes = selected_modes.size()
assert n_selection_rounds == tr.get_n_nodes()
n_rounds = n_selection_rounds + 1

# %%
generator = torch.Generator().manual_seed(3)

h_teacher = torch.randn(L, q, dtype=dtype, generator=generator)

wt_oh = sampling.sample_indep_sites(h_teacher, n_samples=1, generator=generator).squeeze()
torch.nn.functional.cosine_similarity(wt_oh, h_teacher.exp()).mean()
# Out:
# tensor(0.6907)

# %%
mutation_rate = 0.3
k_teacher = utils.field_from_wildtype(wt_oh, mutation_rate)
J_teacher = utils.rand_coupling_matrix(L, q, dtype=dtype)

Ns0_teacher = energy_models.IndepSites(k_teacher)
ps_teacher = selex_distribution.MultiModeDistribution(energy_models.Potts(J_teacher, h_teacher), normalized=False)
model_teacher = selex_distribution.MultiRoundDistribution(Ns0_teacher, ps_teacher, tr, selected_modes)
model_teacher.train(mode=False);

# %%
n_chains = 10**5
chains_teacher = training.init_chains(n_rounds, n_chains, L, q, dtype=dtype)

# %%
n_sweeps = 1
energies = model_teacher.sample(chains_teacher, n_sweeps)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 n_sweeps = 1
# ----> 2 energies = model_teacher.sample(chains_teacher, n_sweeps)
#
# File ~/Aptamer2025py/selex_distribution.py:125, in MultiRoundDistribution.sample(self, chains, n_sweeps, beta)
#     123 for t in torch.arange(n_rounds):
#     124     with torch.no_grad():
# --> 125         energy_t = sampling.sample_metropolis(self, chains, t, n_sweeps, beta=beta)
#     126         energies[t] = energy_t
#     128 return energies
#
# File ~/Aptamer2025py/sampling.py:45, in sample_metropolis(model, chains, t, n_sweeps, beta)
#      43 with torch.no_grad():
#      44     chains_t = chains.select(0, t)
# ---> 45     chains_t, energies = _sample_metropolis(model, chains_t, t, n_steps, beta)
#      46     chains[t] = chains_t
#      47 return energies
#
# File ~/Aptamer2025py/.pixi/envs/default/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~/Aptamer2025py/sampling.py:30, in _sample_metropolis(model, chains, t, n_steps, beta)
#      27 chains_flat_proposal = chains_flat_zeroed.scatter(1, new_token_indices, 1)
#      29 chains_proposal = chains_flat_proposal.view(B, L, q)
# ---> 30 e_proposal = model.compute_energy_up_to_round(chains_proposal, t)
#      32 metropolis_acceptance_mask = torch.log(torch.rand(B, device=device)) < beta * (e_current - e_proposal)
#      34 chains = torch.where(metropolis_acceptance_mask.view(B, 1, 1), chains_proposal, chains)
#
# File ~/Aptamer2025py/selex_distribution.py:98, in MultiRoundDistribution.compute_energy_up_to_round(self, x, t)
#      96     return torch.zeros(x.size(0), device=x.device)
#      97 logNs0 = - self.round_zero.compute_energy(x)
# ---> 98 logps = - self.selection_energy_up_to_round(x, t)
#      99 return - (logps + logNs0)
#
# File ~/Aptamer2025py/selex_distribution.py:90, in MultiRoundDistribution.selection_energy_up_to_round(self, x, t)
#      88 ancestors = self.tree.ancestors_of(t-1)
#      89 normalized_selection_strength = self.selection_strength / self.selection_strength.sum(0, keepdim=True)
# ---> 90 return self.selection.compute_energy(x, selected=self.selected_modes[ancestors],
#      91                                      selection_strength=normalized_selection_strength[ancestors])
#
# File ~/Aptamer2025py/selex_distribution.py:33, in MultiModeDistribution.compute_energy(self, x, selected, selection_strength)
#      31 if selection_strength is None:
#      32     selection_strength = torch.ones(selected.size(0), dtype=x.dtype, device=x.device)
# ---> 33 minus_en_tuple = tuple(- mode.compute_energy(x) for mode in self.modes)
#      34 minus_en = torch.stack(minus_en_tuple, dim=1)
#      35 if self.normalized == True:
#
# File ~/Aptamer2025py/selex_distribution.py:33, in <genexpr>(.0)
#      31 if selection_strength is None:
#      32     selection_strength = torch.ones(selected.size(0), dtype=x.dtype, device=x.device)
# ---> 33 minus_en_tuple = tuple(- mode.compute_energy(x) for mode in self.modes)
#      34 minus_en = torch.stack(minus_en_tuple, dim=1)
#      35 if self.normalized == True:
#
# File ~/Aptamer2025py/energy_models.py:93, in Potts.compute_energy(self, x)
#      91 couplings_flat = (self.J * self.mask).reshape(L * q, L * q)
#      92 bias_term = x_flat @ bias_flat
# ---> 93 coupling_term = torch.sum(x_flat * (x_flat @ couplings_flat), dim=1)
#      94 return - bias_term - 0.5 * coupling_term
#
# KeyboardInterrupt:

# %% [markdown]
# ## Learn

# %%
sequences_oh = chains_teacher
total_reads = total_reads = torch.Tensor([sequences_oh.shape[1] for _ in range(n_rounds)])

# %%
k = torch.randn(L, q, dtype=dtype)
h = torch.randn(L, q, dtype=dtype)
J = utils.rand_coupling_matrix(L, q, dtype=dtype, rescaling=1e-4)

Ns0 = energy_models.IndepSites(k)
ps = selex_distribution.MultiModeDistribution(energy_models.Potts(J, h), normalized=False)
model = selex_distribution.MultiRoundDistribution(Ns0, ps, tr, selected_modes)

# %%
batch_size = 10**4
data_loaders = [data_loading.SelexRoundDataLoader(sequences_oh[id], batch_size=batch_size, device=torch.device('cpu')) 
                for id in range(n_rounds)]

# %%
n_chains = 10**4
chains = training.init_chains(n_rounds, n_chains, L, q, dtype=dtype)
log_weights = torch.zeros(n_rounds, n_chains, dtype=dtype)

# %%
callbacks = [callback.ConvergenceMetricsCallback(), callback.TeacherStudentCallback(model_teacher)]

# %%
lr = 0.05
weight_decay = 0.0
optimizer = torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay)

# %%
n_sweeps = 10
target_pearson = 1
max_epochs = 1000

training.train(model, data_loaders, total_reads, chains, n_sweeps, max_epochs, target_pearson, 
               callbacks=callbacks, log_weights=log_weights, lr=lr,
               optimizer=optimizer)
# Out:
#  0.00%[                                                                                                       …

# %%
callbacks[0].plot();

# %%
callbacks[1].plot(figsize=(7,3))
print('POTTS')
# Out:
# POTTS

# %%
callbacks[1].plot_pearson_energies(figsize=(7,3));

# %%
X = model.round_zero.set_zerosum_gauge().h.detach().reshape(-1)
Y = model_teacher.round_zero.set_zerosum_gauge().h.detach().reshape(-1)
plt.plot(Y, Y,ls='--', color='gray', alpha=1)
plt.scatter(X, Y)
torch.corrcoef(torch.stack([X,Y]))[0,1].item()

# %%
X = model.selection.modes[0].set_zerosum_gauge().h.detach().reshape(-1)
Y = model_teacher.selection.modes[0].set_zerosum_gauge().h.detach().reshape(-1)
plt.plot(Y, Y,ls='--', color='gray', alpha=1)
plt.scatter(X, Y)
torch.corrcoef(torch.stack([X,Y]))[0,1].item()

# %%
X = model.selection.modes[0].set_zerosum_gauge().J.detach().reshape(-1)
Y = model_teacher.selection.modes[0].set_zerosum_gauge().J.detach().reshape(-1)
plt.plot(Y, Y,ls='--', color='gray', alpha=1)
plt.scatter(X, Y)
torch.corrcoef(torch.stack([X,Y]))[0,1].item()

# %% [markdown]
# ## Compute energies for sequences far away from the wildtype

# %%
wt_far_oh = one_hot(torch.randint(q, (L,)))
k_far = utils.field_from_wildtype(wt_far_oh, mutation_rate)
hamming(wt_oh, wt_far_oh)

# %%
X_far = sampling.sample_indep_sites(k_far, n_samples=chains_teacher[0].size(0))
X_close = sequences_oh[0]

# %%
fig, ax = plt.subplots(figsize=(6,3))
ax.hist(hamming(wt_oh, X_close), label='Library round zero', bins=L+1, density=True)
ax.hist(hamming(wt_oh, X_far), label='Data far away', bins=L+1, density=True)
ax.set_xlabel('Hamming from WT')
ax.legend();

# %%
fig, axes = plt.subplots(1, n_rounds+1, figsize=(12, 3))

for t in range(n_rounds):
    ax = axes[t]
    en_teacher = model_teacher.compute_energy_up_to_round(X_close, t).detach()
    en_student = model.compute_energy_up_to_round(X_close, t).detach()
    ax.scatter(en_teacher, en_student, label='Close to WT', s=2)
    en_teacher = model_teacher.compute_energy_up_to_round(X_far, t).detach()
    en_student = model.compute_energy_up_to_round(X_far, t).detach()
    ax.scatter(en_teacher, en_student, label='Far from WT', s=2)
    ax.legend()
    ax.set_xlabel('logNst - teacher'); ax.set_ylabel('logNst - student')
    ax.set_title(f'Round {t}')
    
ax = axes[-1]
en_teacher = model_teacher.selection_energy_at_round(X_close, 1).detach()
en_student = model.selection_energy_at_round(X_close, 1).detach()
ax.scatter(en_teacher, en_student, label='Close to WT', s=2)
en_teacher = model_teacher.selection_energy_at_round(X_far, 1).detach()
en_student = model.selection_energy_at_round(X_far, 1).detach()
ax.scatter(en_teacher, en_student, label='Far from WT', s=2)
ax.legend()
ax.set_xlabel('logps - teacher'); ax.set_ylabel('logps - student')
ax.set_title(f'Selection')
fig.tight_layout()

print('POTTS')

# %%
n_sweeps = 20
n_chains = 10**5
chains_student = training.init_chains(n_rounds, n_chains, L, q, dtype=dtype)
_ = model.sample(chains_student, n_sweeps)

# %%
fig, axes = plt.subplots(1, 3, figsize=(12,4))
markersize = 1
for t in range(n_rounds):
    pcs_gen, pcs_data = utils.compute_pca(chains_student[t], sequences_oh[t])
    ax = axes[t]
    ax.scatter(pcs_data[:,0], pcs_data[:,1], label='Data', s=markersize)
    ax.scatter(pcs_gen[:,0], pcs_gen[:,1], label='Generated', s=markersize, alpha=0.1)
    ax.set_xlabel('PC 1'); ax.set_ylabel('PC 2')
    ax.set_title(f'Round {t}')
    ax.legend()
fig.suptitle('PCA on teacher student, indep sites')
fig.tight_layout()

# %%
t = 0
pcs, _ = utils.compute_pca(sequences_oh[t], chains_student[t])
energies = model_teacher.compute_energy_up_to_round(sequences_oh[t], t).detach()
plt.scatter(pcs[:,0], pcs[:,1], label='Data', s=markersize, c=energies)
plt.colorbar()
