# %%
import sys
sys.path.append('..')

import utils, selex_dca, indep_sites
import adabmDCA
import selex_distribution, energy_models, tree, data_loading, training, callback, sampling

import torch
from utils import one_hot
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
# Out:
# /home/scrotti/Aptamer2025py/selex_dca.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
experiment_id = "Dop8V030"
round_ids = ["ARN", "R01", "R02N"]

device = torch.device("cpu")
dtype = torch.float64

# %%
sequences = [utils.sequences_from_file(experiment_id, round_id, device) for round_id in round_ids]

# %%
sequences_oh = [one_hot(seq).to(dtype=dtype, device=device) for seq in sequences]

# %%
total_reads = torch.Tensor([s.shape[0] for s in sequences_oh]).to(device)
fi0, _, _ = utils.frequences_from_sequences_oh(sequences_oh[0])

# %%
L, q = sequences_oh[0][0].shape
k = torch.log(fi0)
h = torch.zeros(L, q, dtype=dtype, device=device)
J = torch.zeros(L, q, L, q, dtype=dtype, device=device)

tr = tree.Tree()
tr.add_node(-1)
tr.add_node(0)

selected_modes = torch.BoolTensor([[1],[1]]).to(device)

Ns0 = energy_models.IndepSites(k)
potts = energy_models.Potts(J, h)
indep = energy_models.IndepSites(h)
ps = selex_distribution.MultiModeDistribution(potts, normalized=False)
model = selex_distribution.MultiRoundDistribution(Ns0, ps, tr, selected_modes)

# %%
batch_size = 10**6
data_loaders = [data_loading.SelexRoundDataLoader(seq_oh, batch_size=batch_size) for seq_oh in sequences_oh]
n_rounds = len(data_loaders)

# %%
n_chains = 10**4

chains = training.init_chains(n_rounds, n_chains, L, q, device, dtype)
log_weights = torch.zeros(n_rounds, n_chains, device=device, dtype=dtype)

# %%
callbacks = [callback.ConvergenceMetricsCallback(), callback.PearsonCovarianceCallback()]

# %%
# %load_ext line_profiler

# %%
n_sweeps = 10
lr = 0.01
target_pearson = 1
max_epochs = 500

# %lprun -f training.train training.train(model, data_loaders, total_reads, chains, n_sweeps, lr, max_epochs, target_pearson, callbacks=callbacks)
# Out:
#  0.00%[                              ] Epoch: 0/500 [00:00, ?it/s]
# Timer unit: 1e-09 s
#
# Total time: 4978.44 s
# File: /home/scrotti/Aptamer2025py/training.py
# Function: train at line 73
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     73                                           def train(
#     74                                               model: selex_distribution.MultiRoundDistribution,
#     75                                               data_loaders,
#     76                                               total_reads,
#     77                                               chains: torch.Tensor,
#     78                                               n_sweeps: int,
#     79                                               lr: float,
#     80                                               max_epochs: int,
#     81                                               target_pearson = 0.999,
#     82                                               thresh_slope = 1e-2,
#     83                                               l2reg: float = 0.0,
#     84                                               log_weights: torch.Tensor | None = None,
#     85                                               callbacks = [ConvergenceMetricsCallback()],
#     86                                               update_chains = update_chains_default()
#     87                                           ):
#     88         1      35369.0  35369.0      0.0      n_rounds = len(chains)
#     89         1        670.0    670.0      0.0      assert chains.shape[0] == n_rounds
#     90         1     886874.0 886874.0      0.0      normalized_total_reads = total_reads / total_reads.sum(0, keepdim=True)
#     91
#     92         1       1532.0   1532.0      0.0      n_chains = chains.shape[1]
#     93         1       2183.0   2183.0      0.0      device=chains.device
#     94         1       2794.0   2794.0      0.0      dtype=chains.dtype
#     95         1      96412.0  96412.0      0.0      log_n_chains = torch.log(torch.tensor(n_chains, device=device, dtype=dtype)).item()
#     96
#     97         1 1203936671.0  1.2e+09      0.0      optimizer = torch.optim.SGD(model.parameters(), lr=lr, weight_decay=l2reg)
#     98
#     99         1        661.0    661.0      0.0      log_likelihood = - log_n_chains
#    100         1        300.0    300.0      0.0      if log_weights is None:
#    101         1      62075.0  62075.0      0.0          log_weights = torch.zeros(n_rounds, n_chains, device=device, dtype=dtype)
#    102
#    103         1        371.0    371.0      0.0      epochs = 0
#    104         1        330.0    330.0      0.0      converged = (epochs > max_epochs)
#    105         3       1671.0    557.0      0.0      for callback in callbacks:
#    106         2   24623470.0 1.23e+07      0.0          callback.before_training(max_epochs=max_epochs)
#    107
#    108       502     348877.0    695.0      0.0      while not converged:
#    109       501  101685519.0 202965.1      0.0          optimizer.zero_grad()
#    110       501   46318253.0  92451.6      0.0          L_model = L_data = 0
#    111                                                   # log_likelihood = torch.Tensor(0)
#    112      2004    4464948.0   2228.0      0.0          for t in range(n_rounds):
#    113                                                       # update chains
#    114      3006   60298533.0  20059.4      0.0              with torch.no_grad():
#    115      1503     3.25e+12 2.16e+09     65.3                  e = update_chains(chains, t, model, n_sweeps)
#    116                                                       # compute gradient
#    117      1503 4911986129.0 3.27e+06      0.1              L_m = compute_moments_model_at_round(model, chains[t].clone(), t)
#    118      1503   28096173.0  18693.4      0.0              L_model = L_model + normalized_total_reads[t] * L_m
#    119
#    120                                                       # extract batch of data from round t
#    121      1503     5.44e+11 3.62e+08     10.9              data_batch = data_loaders[t].get_batch()
#    122      1503     5.89e+11 3.92e+08     11.8              L_d = compute_moments_data_at_round(model, data_batch, t)
#    123      1503   59826169.0  39804.5      0.0              L_data = L_data + normalized_total_reads[t] * L_d
#    124                                                       # logZt = (torch.logsumexp(log_weights[t], dim=0)).item() - log_n_chains
#    125                                                       # log_likelihood += normalized_total_reads[t] * (- L_d - logZt)
#    126
#    127                                                       # TODO: compute round-wise convergence metrics
#    128
#    129                                                   # Compute gradient
#    130       501 7903237871.0 1.58e+07      0.2          grad_model = compute_grad_model(model, L_model, retain_graph=True)
#    131                                                   # grad_model = compute_grad_model_indep(model)
#    132                                                   # grad_data = grad_data_cached
#    133       501     5.69e+11 1.14e+09     11.4          grad_data = compute_grad_data(model, L_data, retain_graph=False)
#    134       501  118945337.0 237415.8      0.0          grad_total = compute_total_gradient(model, grad_model, grad_data)
#    135                                                   # do gradient step on params
#    136       501  177525976.0 354343.3      0.0          optimizer.step()
#    137
#    138       501     332382.0    663.4      0.0          epochs += 1
#    139       501     247338.0    493.7      0.0          converged = (epochs > max_epochs)
#    140
#    141                                                   # callbacks
#    142      1503    1198029.0    797.1      0.0          for callback in callbacks:
#    143      2004     1.31e+10 6.53e+06      0.3              c = callback.after_step(model=model, chains=chains, total_reads=total_reads,
#    144      1002     254521.0    254.0      0.0                           log_likelihood = log_likelihood, epochs=epochs,
#    145      1002     259906.0    259.4      0.0                           grad_model=grad_model, grad_data=grad_data, grad_total=grad_total,
#    146      1002     267755.0    267.2      0.0                           target_pearson=target_pearson, thresh_slope=thresh_slope)
#    147      1002     909700.0    907.9      0.0              converged = converged or c

# %%
callbacks[0].plot();

# %%
fig, ax = callbacks[1].plot()
ax.axhline(1, color='r', linestyle='--')

# %%
from IPython.display import display, Latex

potts_zerosum = potts.set_zerosum_gauge()
# potts_zerosum = potts

pl, ax = plt.subplots(figsize=(3,3))
F = selex_dca.get_contact_map(potts_zerosum.J.detach())
im = ax.imshow(F)
ax.set_xlabel("i"); ax.set_ylabel("i")
ax.set_title(experiment_id)
plt.colorbar(im)
plt.tight_layout()
# im.set_clim(-0.0015, 0.0030)
display(Latex("$F_{ij}=\\sqrt {\\sum_{ab}(J_{ij}^{ab})^2}$"))
# Out:
# $F_{ij}=\sqrt {\sum_{ab}(J_{ij}^{ab})^2}$
