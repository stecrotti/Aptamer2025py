# %%
import sys
sys.path.append('..')

import utils, selex_dca, indep_sites
import adabmDCA
import selex_distribution, energy_models, tree, data_loading, training, callback

import torch
from utils import one_hot
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from adabmDCA.utils import get_device, get_dtype
# Out:
# /Users/scrotti/Aptamer2025py/selex_dca.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
experiment_id = "Dop8V030"
round_ids = ["ARN", "R01", "R02N"]

device = get_device("")
dtype = get_dtype("float64")
# Out:
# Running on CPU

# %%
sequences = [utils.sequences_from_file(experiment_id, round_id, device) for round_id in round_ids]

# %%
Ms = [2*10**4, 3*10**4, 4*10**4]

# %%
sequences_oh = []
for (seq, M) in zip(sequences, Ms):
    perm = torch.randperm(seq.shape[0])
    idx = perm[:M]
    seq_oh = one_hot(seq[idx]).to(dtype=dtype, device=device)
    sequences_oh.append(seq_oh)

# %%
fi_tuple, fij_tuple, total_reads_tuple = zip(*[utils.frequences_from_sequences_oh(s) for s in sequences_oh])
fi = torch.stack(fi_tuple)  # n_rounds, L, q
fij = torch.stack(fij_tuple)      # n_rounds, L, q, L, q
total_reads = torch.tensor(total_reads_tuple, dtype=dtype, device=device)
n_rounds, L, q = fi.size()

# %%
total_reads = torch.Tensor([s.shape[0] for s in sequences_oh])

# %%
L, q = sequences_oh[0][0].shape
k = torch.zeros(L, q, dtype=dtype, device=device)
k = torch.log(fi[0])
h = torch.zeros(L, q, dtype=dtype, device=device)
J = torch.zeros(L, q, L, q, dtype=dtype, device=device)

tr = tree.Tree()
tr.add_node(-1)
tr.add_node(0)

selected_modes = torch.BoolTensor([[1],[1]])

Ns0 = energy_models.IndepSites(k)
potts = energy_models.Potts(J, h)
indep = energy_models.IndepSites(h)
ps = selex_distribution.MultiModeDistribution(potts, normalized=False)
model = selex_distribution.MultiRoundDistribution(Ns0, ps, tr, selected_modes)

# %%
batch_size = 10**6
datasets = [data_loading.SelexRoundDataset(seq_oh) for seq_oh in sequences_oh]
n_rounds = len(datasets) 
data_loaders = [data_loading.SelexRoundDataLoader(seq_oh, batch_size=batch_size) for seq_oh in sequences_oh]

# %%
n_chains = 10**2

chains = training.init_chains(n_rounds, n_chains, L, q, device, dtype)
log_weights = torch.zeros(n_rounds, n_chains, device=device, dtype=dtype)

# %%
callbacks = [callback.ConvergenceMetricsCallback(), callback.PearsonCovarianceCallback()]

# %%
import importlib
importlib.reload(training)
importlib.reload(callback)
importlib.reload(data_loading)
# Out:
# <module 'data_loading' from '/Users/scrotti/Aptamer2025py/data_loading.py'>

# %%
# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
n_sweeps = 10
lr = 0.01
target_pearson = 1
max_epochs = 100

# %lprun -f training.train training.train(model, data_loaders, total_reads, chains, n_sweeps, lr, max_epochs, target_pearson, callbacks=callbacks)
# Out:
#  0.00%[                              ] Epoch: 0/100 [00:00, ?it/s]
# *** KeyboardInterrupt exception caught in code being profiled.
# Timer unit: 1e-09 s
#
# Total time: 55.5413 s
# File: /Users/scrotti/Aptamer2025py/training.py
# Function: train at line 71
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     71                                           def train(
#     72                                               model: selex_distribution.MultiRoundDistribution,
#     73                                               data_loaders,
#     74                                               total_reads,
#     75                                               chains: torch.Tensor,
#     76                                               n_sweeps: int,
#     77                                               lr: float,
#     78                                               max_epochs: int,
#     79                                               target_pearson = 0.999,
#     80                                               thresh_slope = 1e-2,
#     81                                               l2reg: float = 0.0,
#     82                                               log_weights: torch.Tensor | None = None,
#     83                                               callbacks = [ConvergenceMetricsCallback()],
#     84                                               update_chains = update_chains_default()
#     85                                           ):
#     86         1      13000.0  13000.0      0.0      n_rounds = len(chains)
#     87         1          0.0      0.0      0.0      assert chains.shape[0] == n_rounds
#     88         1     252000.0 252000.0      0.0      normalized_total_reads = total_reads / total_reads.sum(0, keepdim=True)
#     89
#     90         1       2000.0   2000.0      0.0      n_chains = chains.shape[1]
#     91         1       1000.0   1000.0      0.0      device=chains.device
#     92         1       1000.0   1000.0      0.0      dtype=chains.dtype
#     93         1     171000.0 171000.0      0.0      log_n_chains = torch.log(torch.tensor(n_chains, device=device, dtype=dtype)).item()
#     94
#     95         1     258000.0 258000.0      0.0      optimizer = torch.optim.SGD(model.parameters(), lr=lr, weight_decay=l2reg)
#     96
#     97         1          0.0      0.0      0.0      log_likelihood = - log_n_chains
#     98         1       1000.0   1000.0      0.0      if log_weights is None:
#     99         1     144000.0 144000.0      0.0          log_weights = torch.zeros(n_rounds, n_chains, device=device, dtype=dtype)
#    100
#    101         1       1000.0   1000.0      0.0      epochs = 0
#    102         1          0.0      0.0      0.0      converged = (epochs > max_epochs)
#    103         3          0.0      0.0      0.0      for callback in callbacks:
#    104         2    9107000.0 4.55e+06      0.0          callback.before_training(max_epochs=max_epochs)
#    105
#    106        46      15000.0    326.1      0.0      while not converged:
#    107        46    4334000.0  94217.4      0.0          optimizer.zero_grad()
#    108        46    1764000.0  38347.8      0.0          L_model = L_data = 0
#    109                                                   # log_likelihood = torch.Tensor(0)
#    110       182     155000.0    851.6      0.0          for t in range(n_rounds):
#    111                                                       # update chains
#    112       274    2567000.0   9368.6      0.0              with torch.no_grad():
#    113       137     5.23e+10 3.82e+08     94.1                  update_chains(chains, t, model, n_sweeps)
#    114                                                       # compute gradient
#    115       136   28122000.0 206779.4      0.1              L_m = compute_moments_model_at_round(model, chains[t].clone(), t)
#    116       136    1063000.0   7816.2      0.0              L_model = L_model + normalized_total_reads[t] * L_m
#    117
#    118                                                       # extract batch of data from round t
#    119       136  362539000.0 2.67e+06      0.7              data_batch = data_loaders[t].get_batch()
#    120       136 1217607000.0 8.95e+06      2.2              L_d = compute_moments_data_at_round(model, data_batch, t)
#    121       136    1495000.0  10992.6      0.0              L_data = L_data + normalized_total_reads[t] * L_d
#    122                                                       # logZt = (torch.logsumexp(log_weights[t], dim=0)).item() - log_n_chains
#    123                                                       # log_likelihood += normalized_total_reads[t] * (- L_d - logZt)
#    124
#    125                                                       # TODO: compute round-wise convergence metrics
#    126
#    127                                                   # Compute gradient
#    128        45   31896000.0 708800.0      0.1          grad_model = compute_grad_model(model, L_model, retain_graph=True)
#    129                                                   # grad_model = compute_grad_model_indep(model)
#    130                                                   # grad_data = grad_data_cached
#    131        45 1473202000.0 3.27e+07      2.7          grad_data = compute_grad_data(model, L_data, retain_graph=False)
#    132        45    4841000.0 107577.8      0.0          grad_total = compute_total_gradient(model, grad_model, grad_data)
#    133                                                   # do gradient step on params
#    134        45    7922000.0 176044.4      0.0          optimizer.step()
#    135
#    136        45      29000.0    644.4      0.0          epochs += 1
#    137        45      12000.0    266.7      0.0          converged = (epochs > max_epochs)
#    138
#    139                                                   # callbacks
#    140       135      60000.0    444.4      0.0          for callback in callbacks:
#    141       180  103780000.0 576555.6      0.2              c = callback.after_step(model=model, chains=chains, total_reads=total_reads,
#    142        90      17000.0    188.9      0.0                           log_likelihood = log_likelihood, epochs=epochs,
#    143        90      12000.0    133.3      0.0                           grad_model=grad_model, grad_data=grad_data, grad_total=grad_total,
#    144        90      15000.0    166.7      0.0                           target_pearson=target_pearson, thresh_slope=thresh_slope)
#    145        90      25000.0    277.8      0.0              converged = converged or c

# %%
callbacks[0].plot();

# %%
callbacks[1].plot();
