# %%
import sys
sys.path.append('..')

import utils, selex_dca, indep_sites
import adabmDCA
import selex_distribution, energy_models, tree, data_loading, training, callback

import torch
from utils import one_hot
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from adabmDCA.utils import get_device, get_dtype

# %%
experiment_id = "Dop8V030"
round_ids = ["ARN", "R01", "R02N"]

device = get_device("")
dtype = get_dtype("float64")
# Out:
# Running on CPU

# %%
sequences = [utils.sequences_from_file(experiment_id, round_id, device) for round_id in round_ids]

# %%
del sequences

# %%
sequences_oh = [one_hot(seq).to(dtype=dtype, device=device) for seq in sequences]

# %%
fi_tuple, fij_tuple, total_reads_tuple = zip(*[utils.frequences_from_sequences_oh(s) for s in sequences_oh])
fi = torch.stack(fi_tuple)  # n_rounds, L, q
fij = torch.stack(fij_tuple)      # n_rounds, L, q, L, q
total_reads = torch.tensor(total_reads_tuple, dtype=dtype, device=device)
n_rounds, L, q = fi.size()

# %%
total_reads = torch.Tensor([s.shape[0] for s in sequences_oh])

# %%
L, q = sequences_oh[0][0].shape
k = torch.zeros(L, q, dtype=dtype, device=device)
k = torch.log(fi[0])
h = torch.zeros(L, q, dtype=dtype, device=device)
J = torch.zeros(L, q, L, q, dtype=dtype, device=device)

tr = tree.Tree()
tr.add_node(-1)
tr.add_node(0)

selected_modes = torch.BoolTensor([[1],[1]])

Ns0 = energy_models.IndepSites(k)
potts = energy_models.Potts(J, h)
indep = energy_models.IndepSites(h)
ps = selex_distribution.MultiModeDistribution(potts, normalized=False)
model = selex_distribution.MultiRoundDistribution(Ns0, ps, tr, selected_modes)

# %%
batch_size = 10**6
datasets = [data_loading.SelexRoundDataset(seq_oh) for seq_oh in sequences_oh]
n_rounds = len(datasets) 
data_loaders = [torch.utils.data.DataLoader(ds, batch_size=batch_size, shuffle=True) for ds in datasets]

# %%
n_chains = 10**3

chains = init_chains(n_rounds, n_chains, L, q, device, dtype)
log_weights = torch.zeros(n_rounds, n_chains, device=device, dtype=dtype)

# %%
callbacks = [callback.ConvergenceMetricsCallback(), callback.PearsonCovarianceCallback()]

# %%
import importlib
importlib.reload(training)
importlib.reload(callback)
# Out:
# <module 'callback' from '/Users/scrotti/Aptamer2025py/callback.py'>

# %%
# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
n_sweeps = 10
lr = 0.01
target_pearson = 1
max_epochs = 500

# %lprun -f training.train training.train(model, data_loaders, total_reads, chains, n_sweeps, lr, max_epochs, target_pearson, callbacks=callbacks)
# Out:
#  0.00%[                              ] Epoch: 0/500 [00:00, ?it/s]
# Timer unit: 1e-09 s
#
# Total time: 29778.7 s
# File: /Users/scrotti/Aptamer2025py/training.py
# Function: train at line 71
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     71                                           def train(
#     72                                               model: selex_distribution.MultiRoundDistribution,
#     73                                               data_loaders,
#     74                                               total_reads,
#     75                                               chains: torch.Tensor,
#     76                                               n_sweeps: int,
#     77                                               lr: float,
#     78                                               max_epochs: int,
#     79                                               target_pearson = 0.999,
#     80                                               thresh_slope = 1e-2,
#     81                                               l2reg: float = 0.0,
#     82                                               log_weights: torch.Tensor | None = None,
#     83                                               callbacks = [ConvergenceMetricsCallback()],
#     84                                               update_chains = update_chains_default()
#     85                                           ):
#     86         1      59000.0  59000.0      0.0      n_rounds = len(chains)
#     87         1       1000.0   1000.0      0.0      assert chains.shape[0] == n_rounds
#     88         1     500000.0 500000.0      0.0      normalized_total_reads = total_reads / total_reads.sum(0, keepdim=True)
#     89
#     90         1       4000.0   4000.0      0.0      n_chains = chains.shape[1]
#     91         1       3000.0   3000.0      0.0      device=chains.device
#     92         1       9000.0   9000.0      0.0      dtype=chains.dtype
#     93         1     173000.0 173000.0      0.0      log_n_chains = torch.log(torch.tensor(n_chains, device=device, dtype=dtype)).item()
#     94
#     95         1     364000.0 364000.0      0.0      optimizer = torch.optim.SGD(model.parameters(), lr=lr, weight_decay=l2reg)
#     96
#     97         1       1000.0   1000.0      0.0      log_likelihood = - log_n_chains
#     98         1          0.0      0.0      0.0      if log_weights is None:
#     99         1      30000.0  30000.0      0.0          log_weights = torch.zeros(n_rounds, n_chains, device=device, dtype=dtype)
#    100
#    101         1          0.0      0.0      0.0      epochs = 0
#    102         1       1000.0   1000.0      0.0      converged = (epochs > max_epochs)
#    103         3       2000.0    666.7      0.0      for callback in callbacks:
#    104         2   10179000.0 5.09e+06      0.0          callback.before_training(max_epochs=max_epochs)
#    105
#    106       502     140000.0    278.9      0.0      while not converged:
#    107       501   62364000.0 124479.0      0.0          optimizer.zero_grad()
#    108       501  103904000.0 207393.2      0.0          L_model = L_data = 0
#    109                                                   # log_likelihood = torch.Tensor(0)
#    110      2004    3154000.0   1573.9      0.0          for t in range(n_rounds):
#    111                                                       # update chains
#    112      3006   39935000.0  13285.1      0.0              with torch.no_grad():
#    113      1503     2.02e+13 1.35e+10     68.0                  update_chains(chains, t, model, n_sweeps)
#    114                                                       # compute gradient
#    115      1503 1280142000.0 851724.6      0.0              L_m = compute_moments_model_at_round(model, chains[t].clone(), t)
#    116      1503   17810000.0  11849.6      0.0              L_model = L_model + normalized_total_reads[t] * L_m
#    117
#    118                                                       # extract batch of data from round t
#    119      1503     7.59e+12 5.05e+09     25.5              data_batch = next(iter(data_loaders[t]))
#    120      1503     7.83e+11 5.21e+08      2.6              L_d = compute_moments_data_at_round(model, data_batch, t)
#    121      1503   40810000.0  27152.4      0.0              L_data = L_data + normalized_total_reads[t] * L_d
#    122                                                       # logZt = (torch.logsumexp(log_weights[t], dim=0)).item() - log_n_chains
#    123                                                       # log_likelihood += normalized_total_reads[t] * (- L_d - logZt)
#    124
#    125                                                       # TODO: compute round-wise convergence metrics
#    126
#    127                                                   # Compute gradient
#    128       501 1864939000.0 3.72e+06      0.0          grad_model = compute_grad_model(model, L_model, retain_graph=True)
#    129                                                   # grad_model = compute_grad_model_indep(model)
#    130                                                   # grad_data = grad_data_cached
#    131       501     1.16e+12 2.31e+09      3.9          grad_data = compute_grad_data(model, L_data, retain_graph=False)
#    132       501  228535000.0 456157.7      0.0          grad_total = compute_total_gradient(model, grad_model, grad_data)
#    133                                                   # do gradient step on params
#    134       501  146233000.0 291882.2      0.0          optimizer.step()
#    135
#    136       501     366000.0    730.5      0.0          epochs += 1
#    137       501     152000.0    303.4      0.0          converged = (epochs > max_epochs)
#    138
#    139                                                   # callbacks
#    140      1503    1713000.0   1139.7      0.0          for callback in callbacks:
#    141      2004 2623228000.0 1.31e+06      0.0              c = callback.after_step(model=model, chains=chains, total_reads=total_reads,
#    142      1002     159000.0    158.7      0.0                           log_likelihood = log_likelihood, epochs=epochs,
#    143      1002     172000.0    171.7      0.0                           grad_model=grad_model, grad_data=grad_data, grad_total=grad_total,
#    144      1002     193000.0    192.6      0.0                           target_pearson=target_pearson, thresh_slope=thresh_slope)
#    145      1002     401000.0    400.2      0.0              converged = converged or c

# %%
callbacks[0].plot();

# %%
callbacks[1].plot();
