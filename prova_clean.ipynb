# %%
import sys
sys.path.append('..')

import utils, selex_dca, indep_sites
import adabmDCA
import selex_distribution, energy_models, tree, data_loading, training, callback

import torch
from utils import one_hot
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from adabmDCA.utils import get_device, get_dtype
# Out:
# /Users/scrotti/Aptamer2025py/selex_dca.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
experiment_id = "Dop8V030"
round_ids = ["ARN", "R01", "R02N"]

device = get_device("")
dtype = get_dtype("float64")
# Out:
# Running on CPU

# %%
sequences = [utils.sequences_from_file(experiment_id, round_id, device) for round_id in round_ids]

# %%
sequences_oh = [one_hot(seq).to(dtype=dtype, device=device) for seq in sequences]

# %%
del sequences

# %%
fi0, _, _ = utils.frequences_from_sequences_oh(sequences_oh[0])

# %%
total_reads = torch.Tensor([s.shape[0] for s in sequences_oh])

# %%
import importlib
importlib.reload(callback)
importlib.reload(data_loading)
importlib.reload(training)
# Out:
# <module 'training' from '/Users/scrotti/Aptamer2025py/training.py'>

# %%
L, q = sequences_oh[0][0].shape
k = torch.zeros(L, q, dtype=dtype, device=device)
k = torch.log(fi0)
h = torch.zeros(L, q, dtype=dtype, device=device)
J = torch.zeros(L, q, L, q, dtype=dtype, device=device)

tr = tree.Tree()
tr.add_node(-1)
tr.add_node(0)

selected_modes = torch.BoolTensor([[1],[1]])

Ns0 = energy_models.IndepSites(k)
potts = energy_models.Potts(J, h)
indep = energy_models.IndepSites(h)
ps = selex_distribution.MultiModeDistribution(potts, normalized=False)
model = selex_distribution.MultiRoundDistribution(Ns0, ps, tr, selected_modes)

# %%
batch_size = 10**6
data_loaders = [data_loading.SelexRoundDataLoader(seq_oh, batch_size=batch_size) for seq_oh in sequences_oh]
n_rounds = len(data_loaders)

# %%
n_chains = 10**3

chains = training.init_chains(n_rounds, n_chains, L, q, device, dtype)
log_weights = torch.zeros(n_rounds, n_chains, device=device, dtype=dtype)

# %%
callbacks = [callback.ConvergenceMetricsCallback(), callback.PearsonCovarianceCallback()]

# %%
n_sweeps = 10
lr = 0.01
target_pearson = 1
max_epochs = 200

# %lprun -f training.train training.train(model, data_loaders, total_reads, chains, n_sweeps, lr, max_epochs, target_pearson, callbacks=callbacks)
# Out:
#  0.00%[                              ] Epoch: 0/200 [00:00, ?it/s]
# *** KeyboardInterrupt exception caught in code being profiled.
# Timer unit: 1e-09 s
#
# Total time: 5799.62 s
# File: /Users/scrotti/Aptamer2025py/training.py
# Function: train at line 71
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     71                                           def train(
#     72                                               model: selex_distribution.MultiRoundDistribution,
#     73                                               data_loaders,
#     74                                               total_reads,
#     75                                               chains: torch.Tensor,
#     76                                               n_sweeps: int,
#     77                                               lr: float,
#     78                                               max_epochs: int,
#     79                                               target_pearson = 0.999,
#     80                                               thresh_slope = 1e-2,
#     81                                               l2reg: float = 0.0,
#     82                                               log_weights: torch.Tensor | None = None,
#     83                                               callbacks = [ConvergenceMetricsCallback()],
#     84                                               update_chains = update_chains_default()
#     85                                           ):
#     86         1      62000.0  62000.0      0.0      n_rounds = len(chains)
#     87         1          0.0      0.0      0.0      assert chains.shape[0] == n_rounds
#     88         1     184000.0 184000.0      0.0      normalized_total_reads = total_reads / total_reads.sum(0, keepdim=True)
#     89
#     90         1       2000.0   2000.0      0.0      n_chains = chains.shape[1]
#     91         1       1000.0   1000.0      0.0      device=chains.device
#     92         1       7000.0   7000.0      0.0      dtype=chains.dtype
#     93         1     140000.0 140000.0      0.0      log_n_chains = torch.log(torch.tensor(n_chains, device=device, dtype=dtype)).item()
#     94
#     95         1     436000.0 436000.0      0.0      optimizer = torch.optim.SGD(model.parameters(), lr=lr, weight_decay=l2reg)
#     96
#     97         1          0.0      0.0      0.0      log_likelihood = - log_n_chains
#     98         1          0.0      0.0      0.0      if log_weights is None:
#     99         1      90000.0  90000.0      0.0          log_weights = torch.zeros(n_rounds, n_chains, device=device, dtype=dtype)
#    100
#    101         1       1000.0   1000.0      0.0      epochs = 0
#    102         1          0.0      0.0      0.0      converged = (epochs > max_epochs)
#    103         3      23000.0   7666.7      0.0      for callback in callbacks:
#    104         2    8486000.0 4.24e+06      0.0          callback.before_training(max_epochs=max_epochs)
#    105
#    106       141      47000.0    333.3      0.0      while not converged:
#    107       141   16538000.0 117290.8      0.0          optimizer.zero_grad()
#    108       141   34839000.0 247085.1      0.0          L_model = L_data = 0
#    109                                                   # log_likelihood = torch.Tensor(0)
#    110       563     562000.0    998.2      0.0          for t in range(n_rounds):
#    111                                                       # update chains
#    112       846    8671000.0  10249.4      0.0              with torch.no_grad():
#    113       423     5.11e+12 1.21e+10     88.0                  update_chains(chains, t, model, n_sweeps)
#    114                                                       # compute gradient
#    115       422  289275000.0 685485.8      0.0              L_m = compute_moments_model_at_round(model, chains[t].clone(), t)
#    116       422    3658000.0   8668.2      0.0              L_model = L_model + normalized_total_reads[t] * L_m
#    117
#    118                                                       # extract batch of data from round t
#    119       422     2.29e+11 5.44e+08      4.0              data_batch = data_loaders[t].get_batch()
#    120       422     2.53e+11 5.99e+08      4.4              L_d = compute_moments_data_at_round(model, data_batch, t)
#    121       422    8864000.0  21004.7      0.0              L_data = L_data + normalized_total_reads[t] * L_d
#    122                                                       # logZt = (torch.logsumexp(log_weights[t], dim=0)).item() - log_n_chains
#    123                                                       # log_likelihood += normalized_total_reads[t] * (- L_d - logZt)
#    124
#    125                                                       # TODO: compute round-wise convergence metrics
#    126
#    127                                                   # Compute gradient
#    128       140  384408000.0 2.75e+06      0.0          grad_model = compute_grad_model(model, L_model, retain_graph=True)
#    129                                                   # grad_model = compute_grad_model_indep(model)
#    130                                                   # grad_data = grad_data_cached
#    131       140      2.1e+11  1.5e+09      3.6          grad_data = compute_grad_data(model, L_data, retain_graph=False)
#    132       140   64492000.0 460657.1      0.0          grad_total = compute_total_gradient(model, grad_model, grad_data)
#    133                                                   # do gradient step on params
#    134       140   48809000.0 348635.7      0.0          optimizer.step()
#    135
#    136       140      83000.0    592.9      0.0          epochs += 1
#    137       140      44000.0    314.3      0.0          converged = (epochs > max_epochs)
#    138
#    139                                                   # callbacks
#    140       420     739000.0   1759.5      0.0          for callback in callbacks:
#    141       560  545457000.0 974030.4      0.0              c = callback.after_step(model=model, chains=chains, total_reads=total_reads,
#    142       280      54000.0    192.9      0.0                           log_likelihood = log_likelihood, epochs=epochs,
#    143       280      39000.0    139.3      0.0                           grad_model=grad_model, grad_data=grad_data, grad_total=grad_total,
#    144       280      51000.0    182.1      0.0                           target_pearson=target_pearson, thresh_slope=thresh_slope)
#    145       280     105000.0    375.0      0.0              converged = converged or c

# %%
callbacks[0].plot();

# %%
fig, ax = callbacks[1].plot()
ax.axhline(1, color='r', linestyle='--')

# %%
from IPython.display import display, Latex

potts_zerosum = potts.set_zerosum_gauge()
# potts_zerosum = potts

pl, ax = plt.subplots(figsize=(3,3))
F = selex_dca.get_contact_map(potts_zerosum.J.detach())
im = ax.imshow(F)
ax.set_xlabel("i"); ax.set_ylabel("i")
ax.set_title(experiment_id)
plt.colorbar(im)
plt.tight_layout()
display(Latex("$F_{ij}=\\sqrt {\\sum_{ab}(J_{ij}^{ab})^2}$"))
# Out:
# $F_{ij}=\sqrt {\sum_{ab}(J_{ij}^{ab})^2}$
