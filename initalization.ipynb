# %%
import sys
sys.path.append('..')

import utils, selex_dca, indep_sites
import adabmDCA
import selex_distribution, energy_models, tree, data_loading, training, callback

import torch
from utils import one_hot
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm

# %%
experiment_id = "Dop8V030"
round_ids = ["ARN", "R01", "R02N"]

device = torch.device("cuda")
dtype = torch.float64

# %%
sequences = [utils.sequences_from_file(experiment_id, round_id, device) for round_id in round_ids]

# %%
sequences_oh = [one_hot(seq).to(dtype=dtype, device=device) for seq in sequences]

# %%
total_reads = torch.Tensor([s.shape[0] for s in sequences_oh]).to(device)
fi0, _, _ = utils.frequences_from_sequences_oh(sequences_oh[0])

# %%
L, q = sequences_oh[0][0].shape
k = torch.zeros(L, q, dtype=dtype, device=device)
k = torch.log(fi0)
h = torch.zeros(L, q, dtype=dtype, device=device)
J = torch.zeros(L, q, L, q, dtype=dtype, device=device)

tr = tree.Tree()
tr.add_node(-1)
tr.add_node(0)

selected_modes = torch.BoolTensor([[1],[1]]).to(device)

Ns0 = energy_models.IndepSites(k)
potts = energy_models.Potts(J, h)
indep = energy_models.IndepSites(h)
ps = selex_distribution.MultiModeDistribution(potts, normalized=False)
model = selex_distribution.MultiRoundDistribution(Ns0, ps, tr, selected_modes)

# %%
batch_size = 10**6
data_loaders = [data_loading.SelexRoundDataLoader(seq_oh, batch_size=batch_size) for seq_oh in sequences_oh]
n_rounds = len(data_loaders)

# %%
n_chains = 10**3

chains = training.init_chains(n_rounds, n_chains, L, q, device, dtype)
log_weights = torch.zeros(n_rounds, n_chains, device=device, dtype=dtype)

# %%
callbacks = [callback.ConvergenceMetricsCallback(), callback.PearsonCovarianceCallback()]

# %%
# %load_ext line_profiler

# %%
n_sweeps = 10
lr = 0.01
target_pearson = 1
max_epochs = 20

# %lprun -f training.train training.train(model, data_loaders, total_reads, chains, n_sweeps, lr, max_epochs, target_pearson, callbacks=callbacks)
# Out:
#  0.00%[                               ] Epoch: 0/20 [00:00, ?it/s]
# *** KeyboardInterrupt exception caught in code being profiled.
# Timer unit: 1e-09 s
#
# Total time: 270.265 s
# File: /home/scrotti/Aptamer2025py/training.py
# Function: train at line 71
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     71                                           def train(
#     72                                               model: selex_distribution.MultiRoundDistribution,
#     73                                               data_loaders,
#     74                                               total_reads,
#     75                                               chains: torch.Tensor,
#     76                                               n_sweeps: int,
#     77                                               lr: float,
#     78                                               max_epochs: int,
#     79                                               target_pearson = 0.999,
#     80                                               thresh_slope = 1e-2,
#     81                                               l2reg: float = 0.0,
#     82                                               log_weights: torch.Tensor | None = None,
#     83                                               callbacks = [ConvergenceMetricsCallback()],
#     84                                               update_chains = update_chains_default()
#     85                                           ):
#     86         1      31973.0  31973.0      0.0      n_rounds = len(chains)
#     87         1        871.0    871.0      0.0      assert chains.shape[0] == n_rounds
#     88         1    5014919.0 5.01e+06      0.0      normalized_total_reads = total_reads / total_reads.sum(0, keepdim=True)
#     89
#     90         1       2523.0   2523.0      0.0      n_chains = chains.shape[1]
#     91         1       2313.0   2313.0      0.0      device=chains.device
#     92         1       2543.0   2543.0      0.0      dtype=chains.dtype
#     93         1     393829.0 393829.0      0.0      log_n_chains = torch.log(torch.tensor(n_chains, device=device, dtype=dtype)).item()
#     94
#     95         1     275997.0 275997.0      0.0      optimizer = torch.optim.SGD(model.parameters(), lr=lr, weight_decay=l2reg)
#     96
#     97         1        570.0    570.0      0.0      log_likelihood = - log_n_chains
#     98         1        270.0    270.0      0.0      if log_weights is None:
#     99         1      42578.0  42578.0      0.0          log_weights = torch.zeros(n_rounds, n_chains, device=device, dtype=dtype)
#    100
#    101         1        320.0    320.0      0.0      epochs = 0
#    102         1        650.0    650.0      0.0      converged = (epochs > max_epochs)
#    103         3       2083.0    694.3      0.0      for callback in callbacks:
#    104         2   22412236.0 1.12e+07      0.0          callback.before_training(max_epochs=max_epochs)
#    105
#    106        13       7691.0    591.6      0.0      while not converged:
#    107        13    3604862.0 277297.1      0.0          optimizer.zero_grad()
#    108        13    1107917.0  85224.4      0.0          L_model = L_data = 0
#    109                                                   # log_likelihood = torch.Tensor(0)
#    110        51     166431.0   3263.4      0.0          for t in range(n_rounds):
#    111                                                       # update chains
#    112        78    2276446.0  29185.2      0.0              with torch.no_grad():
#    113        39     2.48e+11 6.37e+09     91.9                  update_chains(chains, t, model, n_sweeps)
#    114                                                       # compute gradient
#    115        38   16833032.0 442974.5      0.0              L_m = compute_moments_model_at_round(model, chains[t].clone(), t)
#    116        38     949809.0  24995.0      0.0              L_model = L_model + normalized_total_reads[t] * L_m
#    117
#    118                                                       # extract batch of data from round t
#    119        38     1.51e+10 3.97e+08      5.6              data_batch = data_loaders[t].get_batch()
#    120        38  125612047.0 3.31e+06      0.0              L_d = compute_moments_data_at_round(model, data_batch, t)
#    121        38    1382830.0  36390.3      0.0              L_data = L_data + normalized_total_reads[t] * L_d
#    122                                                       # logZt = (torch.logsumexp(log_weights[t], dim=0)).item() - log_n_chains
#    123                                                       # log_likelihood += normalized_total_reads[t] * (- L_d - logZt)
#    124
#    125                                                       # TODO: compute round-wise convergence metrics
#    126
#    127                                                   # Compute gradient
#    128        12   24556058.0 2.05e+06      0.0          grad_model = compute_grad_model(model, L_model, retain_graph=True)
#    129                                                   # grad_model = compute_grad_model_indep(model)
#    130                                                   # grad_data = grad_data_cached
#    131        12   17338369.0 1.44e+06      0.0          grad_data = compute_grad_data(model, L_data, retain_graph=False)
#    132        12    2116674.0 176389.5      0.0          grad_total = compute_total_gradient(model, grad_model, grad_data)
#    133                                                   # do gradient step on params
#    134        12    7181593.0 598466.1      0.0          optimizer.step()
#    135
#    136        12       7560.0    630.0      0.0          epochs += 1
#    137        12       4997.0    416.4      0.0          converged = (epochs > max_epochs)
#    138
#    139                                                   # callbacks
#    140        36      29849.0    829.1      0.0          for callback in callbacks:
#    141        48 6658572956.0 1.39e+08      2.5              c = callback.after_step(model=model, chains=chains, total_reads=total_reads,
#    142        24       8361.0    348.4      0.0                           log_likelihood = log_likelihood, epochs=epochs,
#    143        24       7350.0    306.2      0.0                           grad_model=grad_model, grad_data=grad_data, grad_total=grad_total,
#    144        24       8574.0    357.2      0.0                           target_pearson=target_pearson, thresh_slope=thresh_slope)
#    145        24      22121.0    921.7      0.0              converged = converged or c

# %%
callbacks[0].plot();

# %%
fig, ax = callbacks[1].plot()
ax.axhline(1, color='r', linestyle='--')

# %%
from IPython.display import display, Latex

potts_zerosum = potts.set_zerosum_gauge()
# potts_zerosum = potts

pl, ax = plt.subplots(figsize=(3,3))
F = selex_dca.get_contact_map(potts_zerosum.J.detach())
im = ax.imshow(F)
ax.set_xlabel("i"); ax.set_ylabel("i")
ax.set_title(experiment_id)
plt.colorbar(im)
plt.tight_layout()
# im.set_clim(-0.0015, 0.0030)
display(Latex("$F_{ij}=\\sqrt {\\sum_{ab}(J_{ij}^{ab})^2}$"))
# Out:
# $F_{ij}=\sqrt {\sum_{ab}(J_{ij}^{ab})^2}$
