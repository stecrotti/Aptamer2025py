# %%
import sys
sys.path.append('..')

import utils, selex_dca, indep_sites
import adabmDCA
import selex_distribution, energy_models, tree, data_loading, training, callback, sampling

import torch
from utils import one_hot
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm

# %%
import importlib
importlib.reload(utils)
importlib.reload(selex_distribution)
importlib.reload(energy_models)
importlib.reload(sampling)
# Out:
# <module 'sampling' from '/home/scrotti/Aptamer2025py/sampling.py'>

# %%
experiment_id = "Dop8V030"
round_ids = ["ARN", "R01", "R02N"]

device = torch.device("cuda")
dtype = torch.float64

# %%
sequences = [utils.sequences_from_file(experiment_id, round_id, device) for round_id in round_ids]

# %%
sequences_oh = [one_hot(seq).to(dtype=dtype, device=device) for seq in sequences]

# %%
total_reads = torch.Tensor([s.shape[0] for s in sequences_oh]).to(device)
fi0, _, _ = utils.frequences_from_sequences_oh(sequences_oh[0])

# %%
L, q = sequences_oh[0][0].shape
k = torch.zeros(L, q, dtype=dtype, device=device)
k = torch.log(fi0)
h = torch.zeros(L, q, dtype=dtype, device=device)
J = torch.zeros(L, q, L, q, dtype=dtype, device=device)

tr = tree.Tree()
tr.add_node(-1)
tr.add_node(0)

selected_modes = torch.BoolTensor([[1],[1]]).to(device)

Ns0 = energy_models.IndepSites(k)
potts = energy_models.Potts(J, h)
indep = energy_models.IndepSites(h)
ps = selex_distribution.MultiModeDistribution(potts, normalized=False)
model = selex_distribution.MultiRoundDistribution(Ns0, ps, tr, selected_modes)

# %%
batch_size = 10**6
data_loaders = [data_loading.SelexRoundDataLoader(seq_oh, batch_size=batch_size) for seq_oh in sequences_oh]
n_rounds = len(data_loaders)

# %%
n_chains = 10**4

chains = training.init_chains(n_rounds, n_chains, L, q, device, dtype)
log_weights = torch.zeros(n_rounds, n_chains, device=device, dtype=dtype)

# %%
callbacks = [callback.ConvergenceMetricsCallback(), callback.PearsonCovarianceCallback()]

# %%
# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
n_sweeps = 10
lr = 0.01
target_pearson = 1
max_epochs = 100

# %lprun -f training.train training.train(model, data_loaders, total_reads, chains, n_sweeps, lr, max_epochs, target_pearson, callbacks=callbacks)
# Out:
#  0.00%[                              ] Epoch: 0/100 [00:00, ?it/s]
# *** KeyboardInterrupt exception caught in code being profiled.
# Timer unit: 1e-09 s
#
# Total time: 149.093 s
# File: /home/scrotti/Aptamer2025py/training.py
# Function: train at line 71
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     71
#     72
#     73                                           def train(
#     74                                               model: selex_distribution.MultiRoundDistribution,
#     75                                               data_loaders,
#     76                                               total_reads,
#     77                                               chains: torch.Tensor,
#     78                                               n_sweeps: int,
#     79                                               lr: float,
#     80                                               max_epochs: int,
#     81                                               target_pearson = 0.999,
#     82                                               thresh_slope = 1e-2,
#     83                                               l2reg: float = 0.0,
#     84                                               log_weights: torch.Tensor | None = None,
#     85                                               callbacks = [ConvergenceMetricsCallback()],
#     86         1      36720.0  36720.0      0.0      update_chains = update_chains_default()
#     87         1        771.0    771.0      0.0  ):
#     88         1     801235.0 801235.0      0.0      n_rounds = len(chains)
#     89                                               assert chains.shape[0] == n_rounds
#     90         1       1442.0   1442.0      0.0      normalized_total_reads = total_reads / total_reads.sum(0, keepdim=True)
#     91         1       2023.0   2023.0      0.0
#     92         1       1892.0   1892.0      0.0      n_chains = chains.shape[1]
#     93         1     428476.0 428476.0      0.0      device=chains.device
#     94                                               dtype=chains.dtype
#     95         1     174178.0 174178.0      0.0      log_n_chains = torch.log(torch.tensor(n_chains, device=device, dtype=dtype)).item()
#     96
#     97         1        411.0    411.0      0.0      optimizer = torch.optim.SGD(model.parameters(), lr=lr, weight_decay=l2reg)
#     98         1        320.0    320.0      0.0
#     99         1      39854.0  39854.0      0.0      log_likelihood = - log_n_chains
#    100                                               if log_weights is None:
#    101         1        240.0    240.0      0.0          log_weights = torch.zeros(n_rounds, n_chains, device=device, dtype=dtype)
#    102         1        450.0    450.0      0.0
#    103         3       1802.0    600.7      0.0      epochs = 0
#    104         2   12843739.0 6.42e+06      0.0      converged = (epochs > max_epochs)
#    105                                               for callback in callbacks:
#    106        52      24742.0    475.8      0.0          callback.before_training(max_epochs=max_epochs)
#    107        52   10009464.0 192489.7      0.0
#    108        52    3379885.0  64997.8      0.0      while not converged:
#    109                                                   optimizer.zero_grad()
#    110       207     329347.0   1591.0      0.0          L_model = L_data = 0
#    111                                                   # log_likelihood = torch.Tensor(0)
#    112       312    5040389.0  16155.1      0.0          for t in range(n_rounds):
#    113       156     7.65e+10 4.91e+08     51.3              # update chains
#    114                                                       with torch.no_grad():
#    115       156   40954359.0 262527.9      0.0                  e = update_chains(chains, t, model, n_sweeps)
#    116       156    2759365.0  17688.2      0.0              # compute gradient
#    117                                                       L_m = compute_moments_model_at_round(model, chains[t].clone(), t)
#    118                                                       L_model = L_model + normalized_total_reads[t] * L_m
#    119       156     4.35e+10 2.79e+08     29.2
#    120       155  402770051.0  2.6e+06      0.3              # extract batch of data from round t
#    121       155    4727695.0  30501.3      0.0              data_batch = data_loaders[t].get_batch()
#    122                                                       L_d = compute_moments_data_at_round(model, data_batch, t)
#    123                                                       L_data = L_data + normalized_total_reads[t] * L_d
#    124                                                       # logZt = (torch.logsumexp(log_weights[t], dim=0)).item() - log_n_chains
#    125                                                       # log_likelihood += normalized_total_reads[t] * (- L_d - logZt)
#    126
#    127                                                       # TODO: compute round-wise convergence metrics
#    128        51   70240991.0 1.38e+06      0.0
#    129                                                   # Compute gradient
#    130                                                   grad_model = compute_grad_model(model, L_model, retain_graph=True)
#    131        51   39787725.0 780151.5      0.0          # grad_model = compute_grad_model_indep(model)
#    132        51    6642289.0 130241.0      0.0          # grad_data = grad_data_cached
#    133                                                   grad_data = compute_grad_data(model, L_data, retain_graph=False)
#    134        51   18541001.0 363549.0      0.0          grad_total = compute_total_gradient(model, grad_model, grad_data)
#    135                                                   # do gradient step on params
#    136        51      25535.0    500.7      0.0          optimizer.step()
#    137        51      14411.0    282.6      0.0
#    138                                                   epochs += 1
#    139                                                   converged = (epochs > max_epochs)
#    140       153     151964.0    993.2      0.0
#    141       204     2.84e+10 1.39e+08     19.1          # callbacks
#    142       102      28100.0    275.5      0.0          for callback in callbacks:
#    143       102      28143.0    275.9      0.0              c = callback.after_step(model=model, chains=chains, total_reads=total_reads,
#    144       102      28459.0    279.0      0.0                           log_likelihood = log_likelihood, epochs=epochs,
#    145       102      92455.0    906.4      0.0                           grad_model=grad_model, grad_data=grad_data, grad_total=grad_total,
#    146                                                                    target_pearson=target_pearson, thresh_slope=thresh_slope)
#    147                                                       converged = converged or c

# %%
callbacks[0].plot();

# %%
fig, ax = callbacks[1].plot()
ax.axhline(1, color='r', linestyle='--')

# %%
from IPython.display import display, Latex

potts_zerosum = potts.set_zerosum_gauge()
# potts_zerosum = potts

pl, ax = plt.subplots(figsize=(3,3))
F = selex_dca.get_contact_map(potts_zerosum.J.detach())
im = ax.imshow(F)
ax.set_xlabel("i"); ax.set_ylabel("i")
ax.set_title(experiment_id)
plt.colorbar(im)
plt.tight_layout()
# im.set_clim(-0.0015, 0.0030)
display(Latex("$F_{ij}=\\sqrt {\\sum_{ab}(J_{ij}^{ab})^2}$"))
# Out:
# $F_{ij}=\sqrt {\sum_{ab}(J_{ij}^{ab})^2}$
