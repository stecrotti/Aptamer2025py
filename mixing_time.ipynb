# %%
import sys
sys.path.append('..')

import utils, selex_dca, indep_sites
import adabmDCA
import selex_distribution, energy_models, tree, data_loading, training, callback, sampling

import torch
from utils import one_hot
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
# Out:
# /Users/scrotti/Aptamer2025py/selex_dca.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
dtype = torch.float32

# %%
import importlib
importlib.reload(utils)
importlib.reload(selex_distribution)
importlib.reload(energy_models)
importlib.reload(sampling)
importlib.reload(training)
importlib.reload(callback)
# Out:
# <module 'callback' from '/Users/scrotti/Aptamer2025py/callback.py'>

# %% [markdown]
# ## Generate

# %%
tr = tree.Tree()
tr.add_node(-1, name = "round 1 with selection")
tr.add_node(0, name = "round 2 with selection")

selected_modes = torch.BoolTensor(
    [[1],
     [1]]
)

n_selection_rounds, n_modes = selected_modes.size()
assert n_selection_rounds == tr.get_n_nodes()
n_rounds = n_selection_rounds + 1

# %%
L, q = 5, 2

k_teacher = torch.randn(L, q, dtype=dtype)
h_teacher = torch.randn(L, q, dtype=dtype)
J_teacher = utils.rand_coupling_matrix(L, q, dtype=dtype)

Ns0_teacher = energy_models.IndepSites(k_teacher)
ps_teacher = selex_distribution.MultiModeDistribution(energy_models.Potts(J_teacher, h_teacher), normalized=False)
model_teacher = selex_distribution.MultiRoundDistribution(Ns0_teacher, ps_teacher, tr, selected_modes)
model_teacher.train(mode=False);

# %%
n_chains = 10**4
chains_teacher = training.init_chains(n_rounds, n_chains, L, q, dtype=dtype)

# %%
t = 0
n_max_sweeps = 50

sampling.compute_mixing_time(model_teacher, t, chains[t], n_max_sweeps)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       1 t = 0
#       2 n_max_sweeps = 50
# ----> 4 sampling.compute_mixing_time(model_teacher, t, chains[t], n_max_sweeps)
#
# AttributeError: module 'sampling' has no attribute 'compute_mixing_time'

# %%
n_sweeps = 20
energies = model_teacher.sample(chains_teacher, n_sweeps)

# %% [markdown]
# ## Learn

# %%
sequences_oh = chains_teacher
total_reads = total_reads = torch.Tensor([sequences_oh.shape[1] for _ in range(n_rounds)])

# %%
k = torch.randn(L, q, dtype=dtype)
h = torch.randn(L, q, dtype=dtype)
J = utils.rand_coupling_matrix(L, q, dtype=dtype, rescaling=1e-4)
# J = torch.zeros(L, q, L, q, dtype=dtype)

Ns0 = energy_models.IndepSites(k)
ps = selex_distribution.MultiModeDistribution(energy_models.Potts(J, h), normalized=False)
model = selex_distribution.MultiRoundDistribution(Ns0, ps, tr, selected_modes)

# %%
batch_size = 10**4
data_loaders = [data_loading.SelexRoundDataLoader(sequences_oh[id], batch_size=batch_size, device=torch.device('cpu')) 
                for id in range(n_rounds)]

# %%
n_chains = 10**4
chains = training.init_chains(n_rounds, n_chains, L, q, dtype=dtype)
log_weights = torch.zeros(n_rounds, n_chains, dtype=dtype)

# %%
callbacks = [callback.ConvergenceMetricsCallback(), callback.TeacherStudentCallback(model_teacher)]

# %%
lr = 0.05
weight_decay = 0.0
# optimizer = torch.optim.SGD([
#                             {'params': model.selection.parameters(), 'lr': 10},
#                             {'params': model.round_zero.parameters(), 'lr': lr}
#                         ])
optimizer = torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay)

# %%
n_sweeps = 10
target_pearson = 1
max_epochs = 1000

training.train(model, data_loaders, total_reads, chains, n_sweeps, lr, max_epochs, target_pearson, 
               callbacks=callbacks, log_weights=log_weights,
               optimizer=optimizer)
# Out:
#  0.00%[                             ] Epoch: 0/1000 [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[517], line 5
#       2 target_pearson = 1
#       3 max_epochs = 1000
# ----> 5 training.train(model, data_loaders, total_reads, chains, n_sweeps, lr, max_epochs, target_pearson,
#       6                callbacks=callbacks, log_weights=log_weights,
#       7                optimizer=optimizer)
#
# File ~/Aptamer2025py/training.py:122, in train(model, data_loaders, total_reads, chains, n_sweeps, lr, max_epochs, target_pearson, thresh_slope, l2reg, log_weights, optimizer, callbacks, update_chains)
#     119 for t in ts:
#     120     # update chains and log weights for estimate of normalization
#     121     with torch.no_grad():
# --> 122         energy_model_t = update_chains(chains, t, model, n_sweeps)
#     123         log_weights[t] += energies_AIS[t] - energy_model_t
#     124         energies_AIS[t] = energy_model_t
#
# File ~/Aptamer2025py/training.py:29, in update_chains_default.<locals>.update_chains(chains, t, model, n_sweeps)
#      28 def update_chains(chains, t, model, n_sweeps):
# ---> 29     return sampling.sample_metropolis(model, chains, t, n_sweeps)
#
# File ~/Aptamer2025py/sampling.py:39, in sample_metropolis(model, chains, t, n_sweeps, beta)
#      37 with torch.no_grad():
#      38     chains_t = chains.select(0, t)
# ---> 39     chains_t, energies = _sample_metropolis(model, chains_t, t, n_steps, beta)
#      40     chains[t] = chains_t
#      41 return energies
#
# File ~/Aptamer2025py/sampling.py:24, in _sample_metropolis(model, chains, t, n_steps, beta)
#      21 chains_flat_proposal = chains_flat_zeroed.scatter(1, new_token_indices, 1)
#      23 chains_proposal = chains_flat_proposal.view(B, L, q)
# ---> 24 e_proposal = model.compute_energy_up_to_round(chains_proposal, t)
#      26 metropolis_acceptance_mask = torch.log(torch.rand(B, device=device)) < beta * (e_current - e_proposal)
#      28 chains = torch.where(metropolis_acceptance_mask.view(B, 1, 1), chains_proposal, chains)
#
# File ~/Aptamer2025py/selex_distribution.py:93, in compute_energy_up_to_round(self, x, t)
#      91 if t == -1:
#      92     return torch.zeros(x.size(0), device=x.device)
# ---> 93 logNs0 = - self.round_zero.compute_energy(x)
#      94 logps = - self.selection_energy_up_to_round(x, t)
#      95 return - (logps + logNs0)
#
# File ~/Aptamer2025py/selex_distribution.py:85, in selection_energy_up_to_round(self, x, t)
#      83 if t == 0:
#      84     return torch.zeros(x.size(0), device=x.device)
# ---> 85 ancestors = self.tree.ancestors_of(t-1)
#      86 return self.selection.compute_energy(x, selected=self.selected_modes[ancestors],
#      87                                      selection_strength=self.selection_strength[ancestors])
#
# File ~/Aptamer2025py/selex_distribution.py:33, in MultiModeDistribution.compute_energy(self, x, selected, selection_strength)
#      31 if selection_strength is None:
#      32     selection_strength = torch.ones(selected.size(0), dtype=x.dtype, device=x.device)
# ---> 33 minus_en_tuple = tuple(- mode.compute_energy(x) for mode in self.modes)
#      34 minus_en = torch.stack(minus_en_tuple, dim=1)
#      35 if self.normalized == True:
#
# File ~/Aptamer2025py/selex_distribution.py:33, in <genexpr>(.0)
#      31 if selection_strength is None:
#      32     selection_strength = torch.ones(selected.size(0), dtype=x.dtype, device=x.device)
# ---> 33 minus_en_tuple = tuple(- mode.compute_energy(x) for mode in self.modes)
#      34 minus_en = torch.stack(minus_en_tuple, dim=1)
#      35 if self.normalized == True:
#
# File ~/Aptamer2025py/energy_models.py:92, in Potts.compute_energy(self, x)
#      90 couplings_flat = (self.J * self.mask).reshape(L * q, L * q)
#      91 bias_term = x_flat @ bias_flat
# ---> 92 coupling_term = torch.sum(x_flat * (x_flat @ couplings_flat), dim=1)
#      93 return - bias_term - 0.5 * coupling_term
#
# KeyboardInterrupt:

# %%
callbacks[0].plot();

# %%
callbacks[1].plot(figsize=(7,3))
print('POTTS')
# Out:
# POTTS

# %%
callbacks[1].plot_energies(figsize=(7,3))

# %%
X = model.round_zero.set_zerosum_gauge().h.detach().reshape(-1)
Y = model_teacher.round_zero.set_zerosum_gauge().h.detach().reshape(-1)
plt.plot(Y, Y,ls='--', color='gray', alpha=1)
plt.scatter(X, Y)
torch.corrcoef(torch.stack([X,Y]))[0,1].item()
# Out:
# 0.9973134398460388

# %%
X = model.selection.modes[0].set_zerosum_gauge().h.detach().reshape(-1)
Y = model_teacher.selection.modes[0].set_zerosum_gauge().h.detach().reshape(-1)
plt.plot(Y, Y,ls='--', color='gray', alpha=1)
plt.scatter(X, Y)
torch.corrcoef(torch.stack([X,Y]))[0,1].item()
# Out:
# 0.9400041103363037

# %%
X = model.selection.modes[0].set_zerosum_gauge().J.detach().reshape(-1)
Y = model_teacher.selection.modes[0].set_zerosum_gauge().J.detach().reshape(-1)
plt.plot(Y, Y,ls='--', color='gray', alpha=1)
plt.scatter(X, Y)
torch.corrcoef(torch.stack([X,Y]))[0,1].item()
# Out:
# 0.659606397151947

# %%
n_sweeps = 20
n_chains = 10**5
chains_student = training.init_chains(n_rounds, n_chains, L, q, dtype=dtype)
_ = model.sample(chains_student, n_sweeps)

# %%
fig, axes = plt.subplots(1, 3, figsize=(12,4))
markersize = 1
for t in range(n_rounds):
    pcs_gen, pcs_data = utils.compute_pca(chains_student[t], sequences_oh[t])
    ax = axes[t]
    ax.scatter(pcs_data[:,0], pcs_data[:,1], label='Data', s=markersize)
    ax.scatter(pcs_gen[:,0], pcs_gen[:,1], label='Generated', s=markersize, alpha=0.1)
    ax.set_xlabel('PC 1'); ax.set_ylabel('PC 2')
    ax.set_title(f'Round {t}')
    ax.legend()
fig.suptitle('PCA on teacher student, indep sites')
fig.tight_layout()

# %%
t = 0
pcs, _ = utils.compute_pca(sequences_oh[t], chains_student[t])
energies = model_teacher.compute_energy_up_to_round(sequences_oh[t], t).detach()
plt.scatter(pcs[:,0], pcs[:,1], label='Data', s=markersize, c=energies)
plt.colorbar()
